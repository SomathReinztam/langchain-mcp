# %%
from langchain_google_genai.chat_models import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(
     model='gemini-2.0-flash',
     temperature = 0
)

# %%
question = "how old is the US president?"

# %%
search_tool = {
    "type": "function",
    "function": {
        "name": "google_search",
        "description": "Returns about common facts, fresh events and news from Google Search engine based on a query.",
        "parameters": {
            "type": "object",
            "properties": {
                "query": {
                    "type": "string",
                    "title": "search_query",
                    "description": "Search query to be sent to the search engine"
                }
            },
            "required": ["query"]
        }
    }
}
step1 = llm.invoke(question, tools=[search_tool])
step1
# Out:
# AIMessage(content='', additional_kwargs={'function_call': {'name': 'google_search', 'arguments': '{"query": "age of US president"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--09782ad7-6e4b-4737-bd21-e48146c0819f-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'age of US president'}, 'id': 'db27af46-aee5-43e5-af6b-c7e48a2a82c1', 'type': 'tool_call'}], usage_metadata={'input_tokens': 41, 'output_tokens': 8, 'total_tokens': 49, 'input_token_details': {'cache_read': 0}})

# %%
print(step1.tool_calls)
# Out:
# [{'name': 'google_search', 'args': {'query': 'age of US president'}, 'id': 'db27af46-aee5-43e5-af6b-c7e48a2a82c1', 'type': 'tool_call'}]

# %%
from langchain_core.messages import HumanMessage, ToolMessage

# %%
tool_result = ToolMessage(content="Donald Trump › Age 78 years June 14, 1946\n", tool_call_id=step1.tool_calls[0]["id"])
step2 = llm.invoke(
    [HumanMessage(content=question), step1, tool_result],
    tools=[search_tool]
)
assert len(step2.tool_calls) == 0

print(step2.content)
# Out:
# The US president is 78 years old.

# %%
llm_with_tools = llm.bind(tools=[search_tool])
llm_with_tools.invoke(question)
# Out:
# AIMessage(content='', additional_kwargs={'function_call': {'name': 'google_search', 'arguments': '{"query": "age of US president"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--3cfa604c-5e94-470b-a6ba-3d43c1bea5cf-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'age of US president'}, 'id': 'c29c8d16-85e7-4797-aaf1-8e395b23db87', 'type': 'tool_call'}], usage_metadata={'input_tokens': 41, 'output_tokens': 8, 'total_tokens': 49, 'input_token_details': {'cache_read': 0}})
